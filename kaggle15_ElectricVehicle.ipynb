# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank1202/Kaggle_playground/blob/main/kaggle15_ElectricVehicle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'Electric_Vehicle_Population_Data.csv')
data.head(3)
# Out:
#    VIN (1-10)   County       City State  Postal Code  Model Year      Make  \
# 0  2C4RC1N71H   Kitsap  Bremerton    WA      98311.0      2017.0  CHRYSLER
# 1  2C4RC1N7XL  Stevens   Colville    WA      99114.0      2020.0  CHRYSLER
# 2  KNDC3DLCXN   Yakima     Yakima    WA      98908.0      2022.0       KIA
#
#       Model                   Electric Vehicle Type  \
# 0  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 2       EV6          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible            33.0
# 1            Clean Alternative Fuel Vehicle Eligible            32.0
# 2  Eligibility unknown as battery range has not b...             0.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  23.0     349437882.0
# 1        0.0                   7.0     154690532.0
# 2        0.0                  14.0     219969144.0
#
#                   Vehicle Location        Electric Utility  2020 Census Tract
# 0  POINT (-122.6466274 47.6341188)  PUGET SOUND ENERGY INC       5.303509e+10
# 1     POINT (-117.90431 48.547075)             AVISTA CORP       5.306595e+10
# 2  POINT (-120.6027202 46.5965625)              PACIFICORP       5.307700e+10

# %%
data.shape
# Out:
# (100235, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100235 entries, 0 to 100234
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         100235 non-null  object
#  1   County                                             100233 non-null  object
#  2   City                                               100233 non-null  object
#  3   State                                              100234 non-null  object
#  4   Postal Code                                        100233 non-null  float64
#  5   Model Year                                         100234 non-null  float64
#  6   Make                                               100234 non-null  object
#  7   Model                                              100234 non-null  object
#  8   Electric Vehicle Type                              100234 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  100234 non-null  object
#  10  Electric Range                                     100234 non-null  float64
#  11  Base MSRP                                          100234 non-null  float64
#  12  Legislative District                               100191 non-null  float64
#  13  DOL Vehicle ID                                     100234 non-null  float64
#  14  Vehicle Location                                   100231 non-null  object
#  15  Electric Utility                                   100233 non-null  object
#  16  2020 Census Tract                                  100233 non-null  float64
# dtypes: float64(7), object(10)
# memory usage: 13.0+ MB

# %%
data.isnull().sum()
# Out:
# VIN (1-10)                                            0
# County                                                2
# City                                                  2
# State                                                 1
# Postal Code                                           2
# Model Year                                            1
# Make                                                  1
# Model                                                 1
# Electric Vehicle Type                                 1
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     1
# Electric Range                                        1
# Base MSRP                                             1
# Legislative District                                 44
# DOL Vehicle ID                                        1
# Vehicle Location                                      4
# Electric Utility                                      2
# 2020 Census Tract                                     2
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
data.shape
# Out:
# (100189, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100189 entries, 0 to 100233
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         100189 non-null  object
#  1   County                                             100189 non-null  object
#  2   City                                               100189 non-null  object
#  3   State                                              100189 non-null  object
#  4   Postal Code                                        100189 non-null  float64
#  5   Model Year                                         100189 non-null  float64
#  6   Make                                               100189 non-null  object
#  7   Model                                              100189 non-null  object
#  8   Electric Vehicle Type                              100189 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  100189 non-null  object
#  10  Electric Range                                     100189 non-null  float64
#  11  Base MSRP                                          100189 non-null  float64
#  12  Legislative District                               100189 non-null  float64
#  13  DOL Vehicle ID                                     100189 non-null  float64
#  14  Vehicle Location                                   100189 non-null  object
#  15  Electric Utility                                   100189 non-null  object
#  16  2020 Census Tract                                  100189 non-null  float64
# dtypes: float64(7), object(10)
# memory usage: 13.8+ MB

# %%
data.head(1)
# Out:
#    VIN (1-10)  County       City State  Postal Code  Model Year      Make  \
# 0  2C4RC1N71H  Kitsap  Bremerton    WA      98311.0      2017.0  CHRYSLER
#
#       Model                   Electric Vehicle Type  \
# 0  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            33.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  23.0     349437882.0
#
#                   Vehicle Location        Electric Utility  2020 Census Tract
# 0  POINT (-122.6466274 47.6341188)  PUGET SOUND ENERGY INC       5.303509e+10

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Electric Vehicle Type', data=data)
plt.title('Count of Electric Vehicle Types')
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Electric Range', y='Base MSRP', data=data)
plt.title("Scatter Plot of Electric Range vs. Base MSRP")
plt.xlabel('Electric Range')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Electric Vehicle Type', y='Electric Range', data=data)
plt.title('Box Plot of Electric Range by Electric Vehicle Type')
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Electric Range')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Model Year'], bins=20, kde=True)
plt.title('Histogram of Model Year')
plt.xlabel('Model Year')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 8))
data['Electric Vehicle Type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Electric Vehicle Types')
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_makes = data['Make'].value_counts().nlargest(10)
top_makes.plot(kind='bar', color='skyblue')
plt.title('Top 10 Vehicle Makes')
plt.xlabel('Vehicle Make')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
numeric_columns = data.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = data[numeric_columns].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='Model Year', y='Electric Range', data=data, palette='viridis')
plt.title('Violin Plot of Electric Range by Model Year')
plt.xlabel('Model Year')
plt.ylabel('Electric Range')
plt.xticks(rotation=45)
plt.show()
